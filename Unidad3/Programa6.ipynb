# %% [markdown]
# <a href="https://colab.research.google.com/github/K0900/Simulacion/blob/main/Unidad3/Programa6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simulacion
# ## Unidad 3
# ### Programa 6. Distribución Binomial
#
# Maestro: Rodriguez Rivas Jose Gabriel
#
# Alumno: Gonzalez Frias Camila

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import comb

n = 10
p = 0.30
num_simulaciones = 100
U = np.random.uniform(0, 1, num_simulaciones)

def binomial_pmf(n, k, p):
    return comb(n, k) * (p**k) * ((1 - p)**(n - k))

def binomial_inverse_transform(n, p, U):
    F_k = 0
    k = 0
    while True:
        F_k += binomial_pmf(n, k, p)
        if U <= F_k:
            return k
        k += 1

compras_simuladas = [binomial_inverse_transform(n, p, u) for u in U]

print("Número de clientes que realizaron una compra en cada simulación (día):")
print(compras_simuladas)

plt.hist(compras_simuladas, bins=np.arange(min(compras_simuladas), max(compras_simuladas) + 1) - 0.5, edgecolor='black')
plt.title("Simulación de número de compras diarias (Distribución Binomial)")
plt.xlabel("Número de compras")
plt.ylabel("Frecuencia")

plt.show()
# Out:
# Número de clientes que realizaron una compra en cada simulación (día):
# [2, 3, 3, 2, 3, 1, 2, 2, 4, 3, 6, 3, 3, 4, 1, 3, 3, 4, 2, 4, 1, 2, 6, 4, 2, 1, 3, 4, 3, 0, 0, 3, 1, 2, 4, 2, 2, 1, 3, 1, 1, 3, 3, 1, 5, 4, 3, 3, 4, 3, 4, 3, 5, 4, 4, 6, 2, 4, 4, 3, 6, 1, 5, 2, 4, 2, 6, 3, 3, 2, 4, 5, 1, 5, 4, 2, 2, 0, 2, 5, 1, 5, 4, 1, 3, 4, 4, 6, 3, 2, 4, 4, 1, 4, 5, 6, 4, 3, 3, 3]

# %% [markdown]
# La distribución binomial se usa para modelar situaciones donde hay un número fijo de intentos o ensayos, y en cada uno solo hay dos posibles resultados: éxito o fracaso. Además, la probabilidad de éxito es la misma en cada intento. Esta distribucion se puede usar en la simulación de compras diarias cuando queremos modelar cuántas compras se realizan en un día, asumiendo que cada posible compra es un evento con solo dos resultados: se realiza (éxito) o no se realiza (fracaso).
