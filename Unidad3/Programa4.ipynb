# %% [markdown]
# <a href="https://colab.research.google.com/github/K0900/Simulacion/blob/main/Unidad3/Programa4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simulacion
# ## Unidad 3
# ### Programa 4. Distribución Poisson Ejemplo 1
#
# Maestro: Rodriguez Rivas Jose Gabriel
#
# Alumno: Gonzalez Frias Camila

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

lambda_poisson = 5
n = 100
U = np.random.uniform(0, 1, n)

def poisson_inverse_transform(lambda_poisson, U):
    k = 0
    F_k = np.exp(-lambda_poisson)
    while U > F_k:
        k += 1
        F_k += (lambda_poisson**k * np.exp(-lambda_poisson)) / math.factorial(k)
    return k

demanda_simulada = [poisson_inverse_transform(lambda_poisson, u) for u in U]

print("Demanda diaria simulada:", demanda_simulada)
plt.hist(demanda_simulada, bins=np.arange(0, max(demanda_simulada) + 1) - 0.5, edgecolor='black', density=True)
plt.title("Simulación de demanda diaria (Distribución Poisson)")
plt.xlabel("Número de productos demandados")
plt.ylabel("Frecuencia")

plt.show()
# Out:
# Demanda diaria simulada: [7, 2, 4, 2, 7, 8, 5, 5, 6, 4, 9, 4, 6, 5, 12, 2, 3, 6, 6, 4, 7, 7, 6, 4, 6, 3, 5, 4, 4, 8, 6, 5, 4, 3, 5, 3, 13, 4, 5, 4, 10, 5, 3, 5, 3, 8, 3, 7, 5, 6, 3, 3, 7, 6, 4, 4, 8, 5, 4, 4, 7, 5, 4, 7, 4, 3, 5, 6, 4, 3, 2, 3, 7, 5, 7, 4, 3, 6, 4, 3, 8, 3, 6, 8, 5, 8, 4, 6, 5, 2, 4, 2, 3, 4, 5, 4, 3, 3, 1, 5]

# %% [markdown]
# La distribución de Poisson se usa para modelar eventos que ocurren de manera aleatoria en un período de tiempo o espacio determinado. Se basa en una tasa promedio de ocurrencia, pero los eventos son independientes entre sí.
