# %% [markdown]
# <a href="https://colab.research.google.com/github/K0900/Simulacion/blob/main/Unidad3/Programa5ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simulacion
# ## Unidad 3
# ### Programa 5. Distribución Poisson Ejemplo 2
#
# Maestro: Rodriguez Rivas Jose Gabriel
#
# Alumno: Gonzalez Frias Camila

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

lambda_poisson = 5
num_simulaciones = 100
U = np.random.uniform(0, 1, num_simulaciones)

def poisson_pmf(lambda_poisson, k):
    return (lambda_poisson ** k) * math.exp(-lambda_poisson) / math.factorial(k)

def poisson_inverse_transform(lambda_poisson, U):
    F_k = 0
    k = 0
    while True:
        F_k += poisson_pmf(lambda_poisson, k)
        if U <= F_k:
            return k
        k += 1

llegadas_simuladas = [poisson_inverse_transform(lambda_poisson, u) for u in U]

print("Número de clientes que llegaron en cada simulación (hora):")
print(llegadas_simuladas)

plt.hist(llegadas_simuladas, bins=np.arange(min(llegadas_simuladas), max(llegadas_simuladas) + 1) - 0.5, edgecolor='black')
plt.title("Simulación de llegadas de clientes (Distribución Poisson)")
plt.xlabel("Número de clientes por hora")
plt.ylabel("Frecuencia")

plt.show()
plt.show()
# Out:
# Número de clientes que llegaron en cada simulación (hora):
# [6, 2, 8, 1, 3, 11, 3, 4, 3, 4, 9, 3, 5, 4, 3, 10, 5, 4, 3, 5, 1, 7, 8, 2, 5, 4, 6, 6, 4, 0, 5, 6, 3, 6, 3, 8, 13, 11, 4, 8, 7, 5, 6, 1, 6, 8, 3, 4, 2, 1, 7, 6, 3, 3, 2, 7, 11, 6, 5, 3, 6, 4, 9, 5, 7, 3, 2, 2, 8, 5, 2, 5, 4, 4, 4, 7, 3, 7, 8, 2, 2, 4, 7, 0, 7, 10, 1, 3, 4, 4, 3, 9, 5, 4, 6, 4, 9, 8, 5, 5]

# %% [markdown]
# Esta distribución se aplica cuando los clientes llegan a un negocio, tienda o sistema de servicio de manera aleatoria, pero con una frecuencia promedio conocida. Esto significa que no hay un patrón fijo en las llegadas, pero en promedio se puede estimar cuántos clientes llegan en un cierto período.
